# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
m = readdlm("hihi.txt")
# Out:
# 3393×2 Array{Float64,2}:
#    2.2e-5    0.011111
#    0.090381  0.011236
#    0.179712  0.011364
#    0.268005  0.011494
#    0.355241  0.011628
#    0.441483  0.011765
#    0.526766  0.011905
#    0.611032  0.012048
#    0.694277  0.012195
#    0.776566  0.012346
#    0.857792  0.0125
#    0.938049  0.012658
#    1.01725   0.012821
#    ⋮
#  101.093     0.058824
#  101.11      0.055556
#  101.128     0.052632
#  101.166     0.05
#  101.187     0.047619
#  101.21      0.045455
#  101.232     0.043478
#  101.256     0.041667
#  101.28      0.04
#  101.305     0.038462
#  101.331     0.037037
#  101.358     0.035714

# %%
plot(m[:,1],m[:,2])
# Out:
# <img src="data:image/png;base64,..." />

# %%
n = readdlm("hehe.txt")
targetPayload = n[:,2]*0+20000
# Out:
# 3393-element Array{Float64,1}:
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#      ⋮
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0

# %%
plot(n[:,1],n[:,2], labs="Current Buffer Level")
plot!(n[:,1], a)
# Out:
# <img src="data:image/png;base64,..." />
