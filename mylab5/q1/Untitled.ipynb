# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
m = readdlm("hihi.txt")
gamma = a = m[:,2]*0+33
# Out:
# 3184-element Array{Float64,1}:
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#   ⋮
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0

# %%
plot(m[:,1],m[:,2])
plot(m[:,,m[:,2])
# Out:
# <img src="data:image/png;base64,..." />

# %%
n = readdlm("hehe.txt")
a = n[:,2]*0+20000
# Out:
# 3184-element Array{Float64,1}:
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#      ⋮
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0

# %%
plot(n[:,1],n[:,2], lab="Current Buffer Level")
plot!(n[:,1], a, lab="Target Buffer Level")
# Out:
# <img src="data:image/png;base64,..." />
