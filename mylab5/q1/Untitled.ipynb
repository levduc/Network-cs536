# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
m = readdlm("ssLog3.txt")
gamma = m[:,2]*0+33
# Out:
# 3682-element Array{Float64,1}:
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#   ⋮
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0
#  33.0

# %%
plot(m[:,1],m[:,2], lab="lambda")
plot!(m[:,1],gamma,lab="gamma")
# savefig("stream2.pdf")
# Out:
# <img src="data:image/png;base64,..." />

# %%
n = readdlm("slLog3.txt")
a = n[:,2]*0+20000
# Out:
# 3682-element Array{Float64,1}:
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#      ⋮
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0
#  20000.0

# %%
plot(n[:,1],n[:,2], lab="Current Buffer Level")
plot!(n[:,1], a, lab="Target Buffer Level")
# savefig("listen2.pdf")
# Out:
# <img src="data:image/png;base64,..." />
